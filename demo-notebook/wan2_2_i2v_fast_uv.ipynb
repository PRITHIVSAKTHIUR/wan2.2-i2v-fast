# %% [markdown]
# ## **wan2.2-i2v-fast**
#
# Note: This demo was tested on an **NVIDIA RTX PRO 6000 Blackwell Server Edition**. Check out the demo on Hugging Face.
#
# Demo: [prithivMLmods/wan2.2-i2v-fast](https://huggingface.co/spaces/prithivMLmods/wan2.2-i2v-fast)

# %% [markdown]
# ### **Running with uv**
#
# — Clone the repository

# %%
# !git clone https://github.com/PRITHIVSAKTHIUR/wan2.2-i2v-fast.git
# %cd wan2.2-i2v-fast

# %% [markdown]
# — Sync project

# %%
# !uv sync

# %% [markdown]
# — Run the script

# %%
# !uv run wan2-2_i2v_app.py
